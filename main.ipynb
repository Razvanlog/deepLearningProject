# %%
import numpy as np
import numpy.core.multiarray
import mediapipe as mp
import cv2
import pyvirtualcam



mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

mp_selfie_segment = mp.solutions.selfie_segmentation


bg_image = cv2.imread('"C:\\Users\\Razvan\\Pictures\\aura_bg.png"')

if bg_image is None:
    bg_image = np.zeros((height, width, 3), dtype=np.uint8)
    bg_image[:] = (0, 255, 0)
else:
    bg_image = cv2.resize(bg_image, (width, height))
face_model = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
body_model = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_upperbody.xml')

with pyvirtualcam.Camera(width=width, height=height, fps=fps) as cam:
    print(f'Using virtual camera: {cam.device}')
    if not cap.isOpened():
        print("Cannot open camera")
        exit()
    with mp_selfie_segment.SelfieSegmentation(model_selection=1) as selfie_segmentation:
        while True:
            ret, frame = cap.read()

            if not ret:
                print("Can't receive frame (stream end?). Exiting ...")
                break
            image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = selfie_segmentation.process(image_rgb)

            condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1
            output_image = np.where(condition, image_rgb, bg_image)

            cv2.imshow('frame', output_image)
            # gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            # faces = face_model.detectMultiScale(gray, scaleFactor = 1.1, minNeighbors = 5)
            # image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # image_rgb.flags.writeable = False

            
            # for (x,y,w,h) in faces:
            #     cv2.rectangle(frame, (x,y), (x+w, y+h), (255,0,0), 2)
            #     cv2.putText(frame, 'Face', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255,0,0), 2)
            #     cv2.rectangle(image_rgb, (x,y), (x+w, y+h), (255,0,0), 2)
            #     cv2.putText(image_rgb, 'Face', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255,0,0), 2)
            # bodies = body_model.detectMultiScale(gray, scaleFactor = 1.1, minNeighbors = 5)

            # for (x,y,w,h) in bodies:
            #     cv2.rectangle(frame, (x,y), (x+w, y+h), (255,0,0), 2)
            #     cv2.putText(frame, 'Body', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255,0,0), 2)
            #     cv2.rectangle(image_rgb, (x,y), (x+w, y+h), (255,0,0), 2)
            #     cv2.putText(image_rgb, 'Body', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255,0,0), 2)
            
            cam.send(image_rgb)
            cam.sleep_until_next_frame()
            cv2.imshow('frame', frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        

cap.release()
cv2.destroyAllWindows()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Razvan\miniconda3\envs\bitdefender\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Razvan\miniconda3\envs\bitdefender\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...
